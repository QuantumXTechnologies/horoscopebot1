# %%
from rasa_nlu.training_data import load_data
from rasa_nlu.model import Trainer
from rasa_nlu import config
from rasa_nlu.model import Interpreter

# %%
def train_horoscopebot(data_json, config_file, model_dir):
     training_data = load_data(data_json)
     trainer = Trainer(config.load(config_file))
     trainer.train(training_data)
     model_directory = trainer.persist(model_dir, fixed_model_name ='horoscopebot')

# %%
def predict_intent(text):
    interpreter = Interpreter.load('./models/nlu/default/horoscopebot')
    print(interpreter.parse(text))

# %%
train_horoscopebot('./data/data.json', 'config.json', './models/nlu')
# Out:
# D:\Machine Learning\Anaconda\lib\site-packages\rasa_nlu\training_data\training_data.py:184: UserWarning: Intent 'greeting, How is you?, How are you?' has only 1 training examples! Minimum is 2, training may fail.
#   warnings.warn("Intent '{}' has only {} training examples! "
# D:\Machine Learning\Anaconda\lib\site-packages\rasa_nlu\training_data\training_data.py:184: UserWarning: Intent 'subscription' has only 1 training examples! Minimum is 2, training may fail.
#   warnings.warn("Intent '{}' has only {} training examples! "
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8392/812069718.py in <module>
# ----> 1 train_horoscopebot('./data/data.json', 'config.json', './models/nlu')
#
# ~\AppData\Local\Temp/ipykernel_8392/1062274528.py in train_horoscopebot(data_json, config_file, model_dir)
#       1 def train_horoscopebot(data_json, config_file, model_dir):
#       2      training_data = load_data(data_json)
# ----> 3      trainer = Trainer(config.load(config_file))
#       4      trainer.train(training_data)
#       5      model_directory = trainer.persist(model_dir, fixed_model_name ='horoscopebot')
#
# D:\Machine Learning\Anaconda\lib\site-packages\rasa_nlu\config.py in load(filename, **kwargs)
#      42     if filename is not None:
#      43         try:
# ---> 44             file_config = utils.read_yaml_file(filename)
#      45         except yaml.parser.ParserError as e:
#      46             raise InvalidConfigError("Failed to read configuration file "
#
# D:\Machine Learning\Anaconda\lib\site-packages\rasa_nlu\utils\__init__.py in read_yaml_file(filename)
#     234 def read_yaml_file(filename):
#     235     fix_yaml_loader()
# --> 236     return yaml.load(read_file(filename, "utf-8"))
#     237
#     238
#
# TypeError: load() missing 1 required positional argument: 'Loader'

# %%
predict_intent("I am looking for my horoscope for today. I am wondering if you can tell me that.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# D:\Machine Learning\Anaconda\lib\site-packages\rasa_nlu\model.py in load(model_dir)
#      73             metadata_file = os.path.join(model_dir, 'metadata.json')
# ---> 74             data = utils.read_json_file(metadata_file)
#      75             return Metadata(data, model_dir)
#
# D:\Machine Learning\Anaconda\lib\site-packages\rasa_nlu\utils\__init__.py in read_json_file(filename)
#     207     """Read json from a file."""
# --> 208     content = read_file(filename)
#     209     try:
#
# D:\Machine Learning\Anaconda\lib\site-packages\rasa_nlu\utils\__init__.py in read_file(filename, encoding)
#     201     """Read text from a file."""
# --> 202     with io.open(filename, encoding=encoding) as f:
#     203         return f.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: './models/nlu/default/horoscopebot\\metadata.json'
#
# During handling of the above exception, another exception occurred:
#
# InvalidProjectError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11544/3224610740.py in <module>
# ----> 1 predict_intent("I am looking for my horoscope for today. I am wondering if you can tell me that.")
#
# ~\AppData\Local\Temp/ipykernel_11544/2687614231.py in predict_intent(text)
#       1 def predict_intent(text):
# ----> 2     interpreter = Interpreter.load('./models/nlu/default/horoscopebot')
#       3     print(interpreter.parse(text))
#
# D:\Machine Learning\Anaconda\lib\site-packages\rasa_nlu\model.py in load(model_dir, component_builder, skip_validation)
#     286         """
#     287
# --> 288         model_metadata = Metadata.load(model_dir)
#     289
#     290         Interpreter.ensure_model_compatibility(model_metadata)
#
# D:\Machine Learning\Anaconda\lib\site-packages\rasa_nlu\model.py in load(model_dir)
#      76         except Exception as e:
#      77             abspath = os.path.abspath(os.path.join(model_dir, 'metadata.json'))
# ---> 78             raise InvalidProjectError("Failed to load model metadata "
#      79                                       "from '{}'. {}".format(abspath, e))
#      80
#
# InvalidProjectError: Failed to load model metadata from 'C:\Users\Mgasa\Natural Language Processing(NLP)\heroscope_bot\models\nlu\default\horoscopebot\metadata.json'. [Errno 2] No such file or directory: './models/nlu/default/horoscopebot\\metadata.json'

# %%
pip list
# Out:
# Package                            VersionNote: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -cikit-learn (d:\machine learning\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (d:\machine learning\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (d:\machine learning\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (d:\machine learning\anaconda\lib\site-packages)
# ---------------------------------- --------------------
# alabaster                          0.7.12
# anaconda-client                    1.9.0
# anaconda-navigator                 2.1.1
# anaconda-project                   0.10.1
# anyio                              2.2.0
# appdirs                            1.4.4
# argh                               0.26.2
# argon2-cffi                        20.1.0
# arrow                              0.13.1
# asn1crypto                         1.4.0
# astroid                            2.6.6
# astropy                            4.3.1
# async-generator                    1.10
# atomicwrites                       1.4.0
# attrs                              21.2.0
# Automat                            20.2.0
# autopep8                           1.5.7
# Babel                              2.9.1
# backcall                           0.2.0
# backports.functools-lru-cache      1.6.4
# backports.shutil-get-terminal-size 1.0.0
# backports.tempfile                 1.0
# backports.weakref                  1.0.post1
# bcrypt                             3.2.0
# beautifulsoup4                     4.10.0
# binaryornot                        0.4.4
# bitarray                           2.3.0
# bkcharts                           0.2
# black                              19.10b0
# bleach                             4.0.0
# blis                               0.9.1
# bokeh                              2.4.1
# boto                               2.49.0
# boto3                              1.24.78
# botocore                           1.27.78
# Bottleneck                         1.3.2
# brotlipy                           0.7.0
# cached-property                    1.5.2
# cachetools                         5.2.0
# catalogue                          2.0.8
# certifi                            2021.10.8
# cffi                               1.14.6
# chardet                            4.0.0
# charset-normalizer                 2.0.4
# click                              8.0.3
# cloudpickle                        0.6.1
# clyent                             1.2.2
# cmake                              3.22.3
# colorama                           0.4.4
# coloredlogs                        15.0.1
# comtypes                           1.1.11
# conda                              4.12.0
# conda-build                        3.21.6
# conda-content-trust                0+unknown
# conda-pack                         0.6.0
# conda-package-handling             1.7.3
# conda-repo-cli                     1.0.4
# conda-token                        0.3.0
# conda-verify                       3.4.2
# confection                         0.0.1
# constantly                         15.1.0
# contextlib2                        0.6.0.post1
# cookiecutter                       1.7.2
# cryptography                       3.4.8
# cycler                             0.10.0
# cymem                              2.0.6
# Cython                             0.29.24
# cytoolz                            0.11.0
# daal4py                            2021.3.0
# dask                               2021.10.0
# debugpy                            1.4.1
# decorator                          5.1.0
# defusedxml                         0.7.1
# diff-match-patch                   20200713
# dill                               0.3.5.1
# distributed                        2021.10.0
# dlib                               19.22.0
# docutils                           0.17.1
# entrypoints                        0.3
# et-xmlfile                         1.1.0
# face-recognition                   1.3.0
# face-recognition-models            0.3.0
# fastcache                          1.1.0
# filelock                           3.3.1
# flake8                             3.9.2
# Flask                              2.1.1
# fonttools                          4.25.0
# fsspec                             2021.10.1
# future                             0.17.1
# gevent                             21.8.0
# glob2                              0.7
# google-api-core                    2.8.1
# google-api-python-client           2.49.0
# google-auth                        2.6.6
# google-auth-httplib2               0.1.0
# google-auth-oauthlib               0.5.1
# googleapis-common-protos           1.56.2
# greenlet                           1.1.1
# gspread                            5.4.0
# h5py                               3.2.1
# HeapDict                           1.0.1
# html5lib                           1.1
# httplib2                           0.20.4
# humanfriendly                      10.0
# hyperlink                          21.0.0
# idna                               3.2
# imagecodecs                        2021.8.26
# imageio                            2.9.0
# imagesize                          1.2.0
# importlib-metadata                 4.11.3
# importlib-resources                5.9.0
# incremental                        21.3.0
# inflection                         0.5.1
# iniconfig                          1.1.1
# intervaltree                       3.1.0
# ipykernel                          6.4.1
# ipython                            7.29.0
# ipython-genutils                   0.2.0
# ipywidgets                         7.6.5
# isort                              5.9.3
# itsdangerous                       2.1.2
# jdcal                              1.4.1
# jedi                               0.18.0
# Jinja2                             2.11.3
# jinja2-time                        0.2.0
# jmespath                           1.0.1
# joblib                             1.1.0
# json5                              0.9.6
# jsonschema                         2.6.0
# jupyter                            1.0.0
# jupyter-client                     6.1.12
# jupyter-console                    6.4.0
# jupyter-core                       4.8.1
# jupyter-server                     1.4.1
# jupyterlab                         3.2.1
# jupyterlab-pygments                0.1.2
# jupyterlab-server                  2.8.2
# jupyterlab-widgets                 1.0.0
# keyring                            23.1.0
# kiwisolver                         1.3.1
# klein                              21.8.0
# langcodes                          3.3.0
# lazy-object-proxy                  1.6.0
# libarchive-c                       2.9
# llvmlite                           0.37.0
# locket                             0.2.1
# lxml                               4.6.3
# MarkupSafe                         1.1.1
# matplotlib                         3.4.3
# matplotlib-inline                  0.1.2
# mccabe                             0.6.1
# menuinst                           1.4.18
# mistune                            0.8.4
# mkl-fft                            1.3.1
# mkl-random                         1.2.2
# mkl-service                        2.4.0
# mock                               4.0.3
# more-itertools                     8.10.0
# mpmath                             1.2.1
# msgpack                            1.0.2
# multipledispatch                   0.6.0
# munkres                            1.1.4
# murmurhash                         1.0.8
# mypy-extensions                    0.4.3
# navigator-updater                  0.2.1
# nbclassic                          0.2.6
# nbclient                           0.5.3
# nbconvert                          6.1.0
# nbformat                           5.1.3
# nest-asyncio                       1.5.1
# networkx                           2.6.3
# nltk                               3.6.5
# nose                               1.3.7
# notebook                           6.4.5
# numba                              0.54.1
# numexpr                            2.7.3
# numpy                              1.20.3
# numpydoc                           1.1.0
# oauthlib                           3.2.0
# olefile                            0.46
# opencv-contrib-python              4.5.5.64
# openpyxl                           3.0.9
# otter-grader                       3.3.0
# packaging                          18.0
# pandas                             1.4.2
# pandocfilters                      1.4.3
# paramiko                           2.7.2
# parso                              0.8.2
# partd                              1.2.0
# path                               16.0.0
# pathlib                            1.0.1
# pathlib2                           2.3.6
# pathspec                           0.7.0
# pathy                              0.6.2
# patsy                              0.5.2
# pdfkit                             1.0.0
# pep8                               1.7.1
# pexpect                            4.8.0
# pickleshare                        0.7.5
# Pillow                             8.4.0
# pip                                22.2.2
# pkginfo                            1.7.1
# pluggy                             0.13.1
# ply                                3.11
# poyo                               0.5.0
# preshed                            3.0.7
# prometheus-client                  0.11.0
# prompt-toolkit                     3.0.20
# protobuf                           3.20.1
# psutil                             5.8.0
# ptyprocess                         0.7.0
# py                                 1.10.0
# pyasn1                             0.4.8
# pyasn1-modules                     0.2.8
# pycodestyle                        2.7.0
# pycosat                            0.6.3
# pycparser                          2.20
# pycurl                             7.44.1
# pydantic                           1.9.1
# pydocstyle                         6.1.1
# pyerfa                             2.0.0
# pyflakes                           2.3.1
# Pygments                           2.10.0
# PyJWT                              2.1.0
# pylint                             2.9.6
# pyls-spyder                        0.4.0
# PyNaCl                             1.4.0
# pyodbc                             4.0.0-unsupported
# pyOpenSSL                          21.0.0
# pyparsing                          3.0.4
# PyPDF2                             2.0.0
# pyreadline                         2.1
# pyreadline3                        3.4.1
# pyrsistent                         0.18.0
# PySocks                            1.7.1
# pytest                             6.2.4
# python-dateutil                    2.8.2
# python-lsp-black                   1.0.0
# python-lsp-jsonrpc                 1.0.0
# python-lsp-server                  1.2.4
# python-on-whales                   0.46.0
# python-slugify                     5.0.2
# pyttsx3                            2.90
# pytz                               2021.3
# PyWavelets                         1.1.1
# pywin32                            228
# pywin32-ctypes                     0.2.0
# pywinpty                           0.5.7
# PyYAML                             6.0
# pyzmq                              22.2.1
# QDarkStyle                         3.0.2
# qstylizer                          0.1.10
# QtAwesome                          1.0.2
# qtconsole                          5.1.1
# QtPy                               1.10.0
# rasa-nlu                           0.13.2
# regex                              2021.8.3
# requests                           2.26.0
# requests-oauthlib                  1.3.1
# rope                               0.19.0
# rsa                                4.8
# Rtree                              0.9.7
# ruamel.yaml                        0.15.100
# ruamel-yaml-conda                  0.15.100
# s3transfer                         0.6.0
# scikit-image                       0.18.3
# scikit-learn                       0.20.4
# scikit-learn-intelex               2021.20210714.120553
# scipy                              1.7.1
# seaborn                            0.11.2
# Send2Trash                         1.8.0
# setuptools                         65.3.0
# simplegeneric                      0.8.1
# simplejson                         3.17.6
# singledispatch                     3.7.0
# sip                                4.19.13
# six                                1.16.0
# smart-open                         5.2.1
# sniffio                            1.2.0
# snowballstemmer                    2.1.0
# sortedcollections                  2.1.0
# sortedcontainers                   2.4.0
# soupsieve                          2.2.1
# spacy                              3.4.1
# spacy-legacy                       3.0.10
# spacy-loggers                      1.0.3
# Sphinx                             4.2.0
# sphinxcontrib-applehelp            1.0.2
# sphinxcontrib-devhelp              1.0.2
# sphinxcontrib-htmlhelp             2.0.0
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               1.0.3
# sphinxcontrib-serializinghtml      1.1.5
# sphinxcontrib-websupport           1.2.4
# spyder                             5.1.5
# spyder-kernels                     2.1.3
# SQLAlchemy                         1.4.22
# srsly                              2.4.4
# statsmodels                        0.12.2
# sweetviz                           2.1.4
# sympy                              1.9
# tables                             3.6.1
# TBB                                0.2
# tblib                              1.7.0
# terminado                          0.9.4
# testpath                           0.5.0
# text-unidecode                     1.3
# textdistance                       4.2.1
# thinc                              8.1.1
# threadpoolctl                      2.2.0
# three-merge                        0.1.1
# tifffile                           2021.7.2
# tinycss                            0.4
# toml                               0.10.2
# toolz                              0.11.1
# tornado                            6.1
# tqdm                               4.62.3
# traitlets                          5.1.0
# Tubes                              0.2.1
# Twisted                            22.8.0
# twisted-iocpsupport                1.0.2
# typed-ast                          1.4.3
# typer                              0.4.1
# typing                             3.7.4.3
# typing-extensions                  3.10.0.2
# ujson                              4.0.2
# unicodecsv                         0.14.1
# Unidecode                          1.2.0
# uritemplate                        4.1.1
# urllib3                            1.26.7
# wasabi                             0.10.1
# watchdog                           2.1.3
# wcwidth                            0.2.5
# webencodings                       0.5.1
# Werkzeug                           2.0.2
# wheel                              0.37.1
# whichcraft                         0.6.1
# widgetsnbextension                 3.5.1
# win-inet-pton                      1.1.0
# win-unicode-console                0.5
# wincertstore                       0.2
# wrapt                              1.12.1
# xlrd                               2.0.1
# XlsxWriter                         3.0.1
# xlwings                            0.24.9
# xlwt                               1.3.0
# xmltodict                          0.12.0
# yapf                               0.31.0
# zict                               2.0.0
# zipp                               3.8.0
# zope.event                         4.5.0
# zope.interface                     5.4.0

# %%
pip install rasa-nlu==0.13.2
# Out:
# Collecting rasa-nlu==0.13.2Note: you may need to restart the kernel to use updated packages.
#   Using cached rasa_nlu-0.13.2-py2.py3-none-any.whl (139 kB)
# Requirement already satisfied: jsonschema in d:\machine learning\anaconda\lib\site-packages (from rasa-nlu==0.13.2) (2.6.0)
# Collecting klein
#   Using cached klein-21.8.0-py2.py3-none-any.whl (88 kB)
# Collecting boto3
#   Using cached boto3-1.24.78-py3-none-any.whl (132 kB)
# Requirement already satisfied: typing in d:\machine learning\anaconda\lib\site-packages (from rasa-nlu==0.13.2) (3.7.4.3)
# Requirement already satisfied: simplejson in d:\machine learning\anaconda\lib\site-packages (from rasa-nlu==0.13.2) (3.17.6)
# Requirement already satisfied: future in d:\machine learning\anaconda\lib\site-packages (from rasa-nlu==0.13.2) (0.17.1)
# Requirement already satisfied: tqdm in d:\machine learning\anaconda\lib\site-packages (from rasa-nlu==0.13.2) (4.62.3)
# Requirement already satisfied: matplotlib in d:\machine learning\anaconda\lib\site-packages (from rasa-nlu==0.13.2) (3.4.3)
# Requirement already satisfied: packaging in d:\machine learning\anaconda\lib\site-packages (from rasa-nlu==0.13.2) (18.0)
# Collecting pathlib
#   Using cached pathlib-1.0.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: six in d:\machine learning\anaconda\lib\site-packages (from rasa-nlu==0.13.2) (1.16.0)
# Requirement already satisfied: requests in d:\machine learning\anaconda\lib\site-packages (from rasa-nlu==0.13.2) (2.26.0)
# Collecting coloredlogs
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Requirement already satisfied: pyyaml in d:\machine learning\anaconda\lib\site-packages (from rasa-nlu==0.13.2) (6.0)
# Requirement already satisfied: numpy>=1.13 in d:\machine learning\anaconda\lib\site-packages (from rasa-nlu==0.13.2) (1.20.3)
# Requirement already satisfied: gevent in d:\machine learning\anaconda\lib\site-packages (from rasa-nlu==0.13.2) (21.8.0)
# Requirement already satisfied: cloudpickle in d:\machine learning\anaconda\lib\site-packages (from rasa-nlu==0.13.2) (0.6.1)
# Collecting botocore<1.28.0,>=1.27.78
#   Downloading botocore-1.27.78-py3-none-any.whl (9.1 MB)
#      ---------------------------------------- 9.1/9.1 MB 257.5 kB/s eta 0:00:00
# Collecting s3transfer<0.7.0,>=0.6.0
#   Using cached s3transfer-0.6.0-py3-none-any.whl (79 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in d:\machine learning\anaconda\lib\site-packages (from boto3->rasa-nlu==0.13.2) (1.0.1)
# Requirement already satisfied: humanfriendly>=9.1 in d:\machine learning\anaconda\lib\site-packages (from coloredlogs->rasa-nlu==0.13.2) (10.0)
# Requirement already satisfied: setuptools in d:\machine learning\anaconda\lib\site-packages (from gevent->rasa-nlu==0.13.2) (65.3.0)
# Requirement already satisfied: cffi>=1.12.2 in d:\machine learning\anaconda\lib\site-packages (from gevent->rasa-nlu==0.13.2) (1.14.6)
# Requirement already satisfied: zope.interface in d:\machine learning\anaconda\lib\site-packages (from gevent->rasa-nlu==0.13.2) (5.4.0)
# Requirement already satisfied: zope.event in d:\machine learning\anaconda\lib\site-packages (from gevent->rasa-nlu==0.13.2) (4.5.0)
# Requirement already satisfied: greenlet<2.0,>=1.1.0 in d:\machine learning\anaconda\lib\site-packages (from gevent->rasa-nlu==0.13.2) (1.1.1)
# Collecting Tubes
#   Using cached Tubes-0.2.1-py2.py3-none-any.whl (59 kB)
# Requirement already satisfied: Werkzeug in d:\machine learning\anaconda\lib\site-packages (from klein->rasa-nlu==0.13.2) (2.0.2)
# Requirement already satisfied: Twisted>=16.6 in d:\machine learning\anaconda\lib\site-packages (from klein->rasa-nlu==0.13.2) (22.8.0)
# Requirement already satisfied: attrs in d:\machine learning\anaconda\lib\site-packages (from klein->rasa-nlu==0.13.2) (21.2.0)
# Requirement already satisfied: hyperlink in d:\machine learning\anaconda\lib\site-packages (from klein->rasa-nlu==0.13.2) (21.0.0)
# Requirement already satisfied: incremental in d:\machine learning\anaconda\lib\site-packages (from klein->rasa-nlu==0.13.2) (21.3.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\machine learning\anaconda\lib\site-packages (from matplotlib->rasa-nlu==0.13.2) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in d:\machine learning\anaconda\lib\site-packages (from matplotlib->rasa-nlu==0.13.2) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\machine learning\anaconda\lib\site-packages (from matplotlib->rasa-nlu==0.13.2) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in d:\machine learning\anaconda\lib\site-packages (from matplotlib->rasa-nlu==0.13.2) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in d:\machine learning\anaconda\lib\site-packages (from matplotlib->rasa-nlu==0.13.2) (8.4.0)
# Requirement already satisfied: idna<4,>=2.5 in d:\machine learning\anaconda\lib\site-packages (from requests->rasa-nlu==0.13.2) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in d:\machine learning\anaconda\lib\site-packages (from requests->rasa-nlu==0.13.2) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\machine learning\anaconda\lib\site-packages (from requests->rasa-nlu==0.13.2) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in d:\machine learning\anaconda\lib\site-packages (from requests->rasa-nlu==0.13.2) (2.0.4)
# Requirement already satisfied: colorama in d:\machine learning\anaconda\lib\site-packages (from tqdm->rasa-nlu==0.13.2) (0.4.4)
# Requirement already satisfied: pycparser in d:\machine learning\anaconda\lib\site-packages (from cffi>=1.12.2->gevent->rasa-nlu==0.13.2) (2.20)
# Requirement already satisfied: pyreadline3 in d:\machine learning\anaconda\lib\site-packages (from humanfriendly>=9.1->coloredlogs->rasa-nlu==0.13.2) (3.4.1)
# Requirement already satisfied: Automat>=0.8.0 in d:\machine learning\anaconda\lib\site-packages (from Twisted>=16.6->klein->rasa-nlu==0.13.2) (20.2.0)
# Requirement already satisfied: twisted-iocpsupport<2,>=1.0.2 in d:\machine learning\anaconda\lib\site-packages (from Twisted>=16.6->klein->rasa-nlu==0.13.2) (1.0.2)
# Requirement already satisfied: constantly>=15.1 in d:\machine learning\anaconda\lib\site-packages (from Twisted>=16.6->klein->rasa-nlu==0.13.2) (15.1.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in d:\machine learning\anaconda\lib\site-packages (from Twisted>=16.6->klein->rasa-nlu==0.13.2) (3.10.0.2)
# Installing collected packages: pathlib, coloredlogs, botocore, Tubes, s3transfer, klein, boto3, rasa-nlu
# Successfully installed Tubes-0.2.1 boto3-1.24.78 botocore-1.27.78 coloredlogs-15.0.1 klein-21.8.0 pathlib-1.0.1 rasa-nlu-0.13.2 s3transfer-0.6.0
# WARNING: Ignoring invalid distribution -cikit-learn (d:\machine learning\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (d:\machine learning\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (d:\machine learning\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (d:\machine learning\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (d:\machine learning\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (d:\machine learning\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (d:\machine learning\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (d:\machine learning\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (d:\machine learning\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (d:\machine learning\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (d:\machine learning\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (d:\machine learning\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (d:\machine learning\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (d:\machine learning\anaconda\lib\site-packages)
